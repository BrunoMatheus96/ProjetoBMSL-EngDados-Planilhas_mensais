# %% [markdown]
# # Fluxos

# %% [markdown]
# ## Fluxo para criação de planilhas mensais

# %%
from src.workflows.planilha_mensal_workflow import workflow_automacao_mensal

workflow_automacao_mensal()
# Out:
# ▶️Iniciando automação...
# ⚫Duplicação
#  ➡️Mês anterior: Março
#  ➡️Mês atual: Abril
#  ⏳Validando existência da planilha do mês atual...
#  ✅Duplicado com sucesso
#  ⏳Carregando...
#
# ⚫Validação e sincronizando planilhas
#  ⏳Tentativa 1 de abrir a planilha: 1ILmNbWWKHAWOg_hDpD-GTN8qAvuw0DDmbp-TxHT5AYI
#  ✅Planilha disponível
#  📄Abas encontradas: ['Alunos']
#  ⏳Tentativa 1 de abrir a planilha: 1DMiUnGzCtuF825yz83nL-KSxhWyTET4L2XdSkUVztL0
#  ✅Planilha disponível
#  📄Abas encontradas: ['Total', 'Manoela Dualib', 'Thiago', 'Isabella', 'Oto', 'Manoela Salton', 'Matheus', 'Patrick', 'Eduardo', 'Laila']
#  ➡️Aba 'Isabella' já existe
#  ➡️Aba 'Thiago' já existe
#  ➡️Aba 'Matheus' já existe
#  ➡️Aba 'Patrick' já existe
#  ➡️Aba 'Manoela Salton' já existe
#  ➡️Aba 'Eduardo' já existe
#  ➡️Aba 'Manoela Dualib' já existe
#  ➡️Aba 'Oto' já existe
#  ✅Aba 'Enrico' criada
#
# ✅Finalizado
