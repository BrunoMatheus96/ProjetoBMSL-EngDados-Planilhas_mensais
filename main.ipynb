# %% [markdown]
# # Fluxos

# %% [markdown]
# ## Fluxo para criação de planilhas mensais

# %%
from src.workflows.planilha_mensal_workflow import rodar_automacao_mensal

rodar_automacao_mensal()
# Out:
# Iniciando automação...
# ⚫Download de Alunos.xlsm
#  ✅Download concluído
#
# ⚫Validação
#  ➡️Mês anterior: Março
#  ➡️Mês atual: Abril
#  📢Arquivo do mês 'Abril' já existe.
#
# ⚫Validação e sincronizando planilhas
# ID que estou usando: 1cwKma2UdD4Y5cLIsxiZTn7pSKjTLWEM79O53aIJ-_jM
# Erro em sincronizar: ❌ spreadsheet_id inválido
#
# ✅Finalizado
