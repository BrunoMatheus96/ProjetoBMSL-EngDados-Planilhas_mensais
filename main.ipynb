# %% [markdown]
# # Fluxos

# %% [markdown]
# ## Fluxo para criação de planilhas mensais

# %%
from src.workflows.planilha_mensal_workflow import workflow_automacao_mensal

workflow_automacao_mensal()
# Out:
# ▶️Iniciando automação...
#
# ⚫Duplicação
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=352114749237-vudit5rr5jk6q2stgbvv8qqil4tp1gmb.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A64488%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=p9pDxgSThs8OJxV7seMzGu89PQLbmA&code_challenge=H7DNCm2nncyJvRaIH0IhAsVg1wiH2FxFgTMCK_Qeyyg&code_challenge_method=S256&access_type=offline
#  ⏳Validando existência da planilha do mês atual...
#     ➡️Mês atual: Abril
#  📢Arquivo do mês 'Abril' já existe.
#
# ⚫Validação e sincronização da planilhas
#  ✅Planilha disponível
#  ✅Planilha disponível
#  📢Aba 'Manoela Salton' já existe
#  📢Linha 'Manoela Salton' já existe
#  📢Aba 'Patrick' já existe
#  📢Linha 'Patrick' já existe
#  📢Aba 'Thiago' já existe
#  📢Linha 'Thiago' já existe
#  📢Aba 'Oto' já existe
#  📢Linha 'Oto' já existe
#  📢Aba 'Eduardo' já existe
#  📢Linha 'Eduardo' já existe
#  📢Aba 'Enrico' já existe
#  📢Linha 'Enrico' já existe
#  📢Aba 'Manoela Dualib' já existe
#  📢Linha 'Manoela Dualib' já existe
#  📢Aba 'Isabella' já existe
#  📢Linha 'Isabella' já existe
#  📢Aba 'Matheus' já existe
#  📢Linha 'Matheus' já existe
#
# ✅Automação finalizada
